# %%
import pandas as pd

Bee_Colony_Loss_2010_2017_df = pd.read_csv("Bee_Colony_Loss_2010_2017.csv")

# %%
Bee_Colony_Loss_2010_2017_df.sample(5)
# Out:
#         Year  Season          State  Total Annual Loss   Beekeepers  \
# 70   2015/16  Annual        Indiana             39.50%          152
# 249  2012/13  Annual  West Virginia             55.80%           60
# 135  2014/15  Annual        Alabama             48.00%           28
# 23   2016/17  Annual   North Dakota             37.80%           17
# 349  2010/11  Annual        Florida             57.70%           57
#
#      Beekeepers Exclusive to State   Colonies  Colonies Exclusive to State  \
# 70                          98.70%       1707                       98.50%
# 249                         93.30%       2736                       19.10%
# 135                         96.40%        504                       98.50%
# 23                          11.80%     163861                        0.00%
# 349                         91.20%      13624                        7.00%
#
#      Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 70          NaN         NaN          NaN          NaN          NaN
# 249         NaN         NaN          NaN          NaN          NaN
# 135         NaN         NaN          NaN          NaN          NaN
# 23          NaN         NaN          NaN          NaN          NaN
# 349         NaN         NaN          NaN          NaN          NaN
#
#      Unnamed: 13  Unnamed: 14
# 70           NaN          NaN
# 249          NaN          NaN
# 135          NaN          NaN
# 23           NaN          NaN
# 349          NaN          NaN
